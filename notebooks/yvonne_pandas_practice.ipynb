# %%
import pandas as pd

# %%
df = pd.DataFrame(
    columns=["Name", "Age", "Height"],
    )
df
# Out:
# Empty DataFrame
# Columns: [Name, Age, Height]
# Index: []

# %%
df.loc[0] = ["Allen", 22, 180]
df
df.loc[1] = ["Jack", 30, 172]
df
# Out:
#     Name  Age  Height
# 0  Allen   22     180
# 1   Jack   30     172

# %%
df["Age"][1] = 28
# Out:
# /var/folders/rn/dnts2tcx26x1x17_ssv5w7500000gn/T/ipykernel_11377/2063534485.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df["Age"][1] = 28

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     180
# 1   Jack   29     172

# %%
df["Weight"] = [75, 80]
df
# Out:
#     Name  Age  Height  Weight
# 0  Allen   22     180      75
# 1   Jack   29     172      80

# %%
df.drop("Weight",axis=1)
# Out:
#     Name  Age  Height
# 0  Allen   22     180
# 1   Jack   29     172

# %%
df
# Out:
#     Name  Age  Height  Weight
# 0  Allen   22     180      75
# 1   Jack   29     172      80

# %%
df = df.drop("Weight",axis=1)
df
# Out:
#     Name  Age  Height
# 0  Allen   22     180
# 1   Jack   29     172

# %%
df.drop(1)
df
# Out:
#     Name  Age  Height
# 0  Allen   22     180
# 1   Jack   29     172

# %%
df = df.drop(1)
df
# Out:
#     Name  Age  Height
# 0  Allen   22     180

# %%
df["Age"] + 10
df
# Out:
#     Name  Age  Height
# 0  Allen   22     180

# %%
df["Age"] + 10
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
df = df["Age"] + 10
df
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
df
# Out:
# 0    32
# Name: Age, dtype: int64

# %%
df = pd.DataFrame(
    columns=["Name", "Age", "Height"],
    )
df
# Out:
# Empty DataFrame
# Columns: [Name, Age, Height]
# Index: []

# %%
df.loc[0] = ["Allen", 22, 180]

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   22     180

# %%
df["Age"] = df["Age"] + 10

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   32     180

# %%
df2 = df.copy()
df2.loc[0, "Age"] = 12

# %%
df
df2
# Out:
#     Name  Age  Height
# 0  Allen   12     180

# %%
df
# Out:
#     Name  Age  Height
# 0  Allen   32     180
